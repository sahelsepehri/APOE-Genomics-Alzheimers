# %% [markdown]
# ## APOE apolipoprotein E [ Homo sapiens (human) ]

# %% [markdown]
# ## Phase 1
# ### Biological and Database Exploration of APOE

# %% [markdown]
# ### 1.1 Why APOE ?

# %% [markdown]
# ### 1.2 Manual Database Investigation [NCBI, Ensembl, ClinVar]

# %% [markdown]
# Phase 1 : Human APOE Gene Data Extraction

# %% [markdown]
# ![APOE-NCBI](attachment:summary2.png)
# ![Genomic context.png](<attachment:Genomic context.png>)

# %%
apoe_human_info = {
    "Gene_Symbol" : "APOE",
    "Official_Full_Name" : "apolipoprotein E",
    "Gene_type" : "protein coding",
    "NCBI_Gene_ID" : "348",
    "Ensembl_ID" : "ENSG00000130203",
    "HGNC_ID" : "HGNC:613",
    "Other_Names" : "AD2, LPG, APO-E, ApoE4, LDLCQ5",
    "Proteins_Counts" : "5",
    "Transcripts_Counts" : "5",
    "Location": "19q13.32",
    "Exon count": "6",
    "Intron count" : "5"  #Exon - 1
}

# %%
import pandas as pd

df = pd.DataFrame(list(apoe_human_info.items()), columns= ["Identifier Type", "Value"])

df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c94fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c94fa_level0_col0" class="col_heading level0 col0" >Identifier Type</th>
#       <th id="T_c94fa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c94fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c94fa_row0_col0" class="data row0 col0" >Gene_Symbol</td>
#       <td id="T_c94fa_row0_col1" class="data row0 col1" >APOE</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c94fa_row1_col0" class="data row1 col0" >Official_Full_Name</td>
#       <td id="T_c94fa_row1_col1" class="data row1 col1" >apolipoprotein E</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c94fa_row2_col0" class="data row2 col0" >Gene_type</td>
#       <td id="T_c94fa_row2_col1" class="data row2 col1" >protein coding</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c94fa_row3_col0" class="data row3 col0" >NCBI_Gene_ID</td>
#       <td id="T_c94fa_row3_col1" class="data row3 col1" >348</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c94fa_row4_col0" class="data row4 col0" >Ensembl_ID</td>
#       <td id="T_c94fa_row4_col1" class="data row4 col1" >ENSG00000130203</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c94fa_row5_col0" class="data row5 col0" >HGNC_ID</td>
#       <td id="T_c94fa_row5_col1" class="data row5 col1" >HGNC:613</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c94fa_row6_col0" class="data row6 col0" >Other_Names</td>
#       <td id="T_c94fa_row6_col1" class="data row6 col1" >AD2, LPG, APO-E, ApoE4, LDLCQ5</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c94fa_row7_col0" class="data row7 col0" >Proteins_Counts</td>
#       <td id="T_c94fa_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c94fa_row8_col0" class="data row8 col0" >Transcripts_Counts</td>
#       <td id="T_c94fa_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c94fa_row9_col0" class="data row9 col0" >Location</td>
#       <td id="T_c94fa_row9_col1" class="data row9 col1" >19q13.32</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c94fa_row10_col0" class="data row10 col0" >Exon count</td>
#       <td id="T_c94fa_row10_col1" class="data row10 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c94fa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c94fa_row11_col0" class="data row11 col0" >Intron count</td>
#       <td id="T_c94fa_row11_col1" class="data row11 col1" >5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![Genomic regions, transcripts, and products2.png](<attachment:Genomic regions, transcripts, and products2.png>)

# %% [markdown]
# Orthologs

# %% [markdown]
# - RNA title:	mRNA-apolipoprotein E, transcript variant 2
# - Protein title:	apolipoprotein E isoform b precursor
# - Protein comment:	isoform b precursor is encoded by transcript variant 2
# - Merged features: NM_000041.4 and NP_000032.1
# - Location:	44,905,796..44,909,393
# - Span on NC_000019.10: 3,598 nt
# - Aligned length:	1,166 nt
# - CDS length:	954 nt
# - Protein length:	317 aa
#
#
# - mRNA RefSeq : NM_000041.4
# - Protein Refseq : NP_000032.1

# %% [markdown]
# ### 1.3 Reproducing Manual Finfings Programmically

# %%
from Bio import Entrez

Entrez.email = "sahelsepehri99@gmail.com"

handle = Entrez.esearch(
    db= "gene",
    term = "APOE[Gene] AND Homo sapians [Organism]"
)

record = Entrez.read(handle)
gene_id = record ["IdList"][0]
print("Gene ID :", gene_id)
# Out:
# Gene ID : 348

# %% [markdown]
# References
#
# - [NCBI](https://www.ncbi.nlm.nih.gov/)
# - [Pandas Documentation](https://pandas.pydata.org/docs/index.html)
# - [Accessing NCBI’s Entrez databases](https://biopython.org/docs/latest/Tutorial/chapter_entrez.html)

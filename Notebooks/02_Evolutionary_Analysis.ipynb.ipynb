# %% [markdown]
# ### ⭐ 1. Introduction

# %% [markdown]
# How is human APOE evolutionarily related to other primates and mammals?

# %% [markdown]
# Species to compare:
# - Human (Homo sapiens)
# - Chimpanzee (Pan troglodytes)
# - Western gorilla (Gorilla gorilla)
# - Bornean orangutan (Pongo pygmaeus)
# - House mouse (Mus musculus) as outgroup
#
# Steps:
# 1. BLAST search to find homologous sequences
# 2. Multiple Sequence Alignment (MSA)
# 3. Phylogenetic tree construction
# 4. Evolutionary interpretation

# %% [markdown]
# ---

# %% [markdown]
# ### ⭐ 2. Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ### ⭐ 3. BLAST Analysis

# %% [markdown]
# [BLAST](https://blast.ncbi.nlm.nih.gov/Blast.cgi)

# %% [markdown]
# Protein BLAST (blastp)

# %% [markdown]
# ![BLASTP](attachment:image.png)

# %% [markdown]
# ![BLAST-reault.png](attachment:image.png)

# %%
# create a dictionary of blastp results
blast_data = {
    'Species': ['Human', 'Bornean orangutan', 'Western lowland gorilla', 'Chimpanzee', 'House mouse'],
    'Scientific Name' : ['Homo sapiens', 'Pongo pygmaeus', 'Gorilla gorilla gorilla', 'Pan troglodytes','Mus musculus'],
    'Accession': ['NP_000032.1', 'Q9GLM7.1', 'Q9GLM8.1', 'NP_001009007.1','NP_001292748.1'],
    'Identity (%)': [100.00, 97.48, 97.48, 97.16, 70.85],
    'Query Cover (%)': [100, 100, 100, 100, 100],
    'E-value': [0.0, 0.0, 0.0, 0.0, '2e-154'],
    'Length' :[317, 317, 317, 317, 311]
}

# Turn the disctionary into the dataframe
df_blast = pd.DataFrame(blast_data)
df_blast.style.set_caption("Description table of BLASTp Results for APOE Protein")
# Out:
# <style type="text/css">
# </style>
# <table id="T_621f4">
#   <caption>Description table of BLASTp Results for APOE Protein</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_621f4_level0_col0" class="col_heading level0 col0" >Species</th>
#       <th id="T_621f4_level0_col1" class="col_heading level0 col1" >Scientific Name</th>
#       <th id="T_621f4_level0_col2" class="col_heading level0 col2" >Accession</th>
#       <th id="T_621f4_level0_col3" class="col_heading level0 col3" >Identity (%)</th>
#       <th id="T_621f4_level0_col4" class="col_heading level0 col4" >Query Cover (%)</th>
#       <th id="T_621f4_level0_col5" class="col_heading level0 col5" >E-value</th>
#       <th id="T_621f4_level0_col6" class="col_heading level0 col6" >Length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_621f4_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# Interpretation :

# %% [markdown]
# ---

# %% [markdown]
# ### Graphic Summary

# %% [markdown]
# ![Graphical Summary](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Distance Tree of Results

# %% [markdown]
# ![Distance_Tree](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### ⭐ Interpretation

# %% [markdown]
# ### ⭐ References
# - [BLAST](https://blast.ncbi.nlm.nih.gov/)
